# %%
import easyocr
reader = easyocr.Reader(['ta','en']) # need to run only once to load model into memory
result = reader.readtext('tamil lang.jpg')
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
result = reader.readtext('tamil full.png')

# %%
result
# Out:
# [([[24, 9], [148, 9], [148, 36], [24, 36]], 'வ்விணையத்', 0.7495142955488385),
#  ([[162, 14], [266, 14], [266, 38], [162, 38]], 'தளமானது', 0.869755525154018),
#  ([[295, 9], [391, 9], [391, 37], [295, 37]],
#   '-ங்களுக்கு',
#   0.5576010630884989),
#  ([[411, 17], [443, 17], [443, 33], [411, 33]], 'அர', 0.9996755689766282),
#  ([[438, 10], [550, 10], [550, 36], [438, 36]],
#   'சாங்கத்தின்',
#   0.8604539009932869),
#  ([[51, 38], [126, 38], [126, 64], [51, 64]], 'மைப்பு,', 0.3800201559575745),
#  ([[175, 45], [199, 45], [199, 61], [175, 61]], '0', 0.42946233358867403),
#  ([[210, 42], [292, 42], [292, 66], [210, 66]], 'வரலாறு,', 0.7506581741750843),
#  ([[302, 38], [404, 38], [404, 62], [302, 62]],
#   'பரிணாமம்',
#   0.6024431037146681),
#  ([[410, 34], [479, 34], [479, 67], [410, 67]], 'மற்றும்', 0.7107350945736932),
#  ([[527, 45], [549, 45], [549, 61], [527, 61]], '', 0.0),
#  ([[6, 66], [38, 66], [38, 92], [6, 92]], 'தற்', 0.9218040704727173),
# ...

# %%
# !pwd
# Out:
# /home/harshit/Documents/Upwork pavan deepak

# %%
# !pip install requests
